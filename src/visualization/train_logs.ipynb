# %%
import seaborn as sns
import matplotlib.pyplot as plt
import json
from os.path import join as pjoin
import os
from src.train.train_utils import load_train_logs


cwd = "/workspaces/cycle_gan_icons_generator"
LOGS_FOLDER = pjoin(cwd, "logs")


logs = load_train_logs(LOGS_FOLDER)
gen_AtoB_losses, gen_BtoA_losses, dis_A_losses, dis_B_losses = logs

# %%
plt.plot(gen_AtoB_losses, label="gen_AtoB_loss")

# %%
plt.plot(gen_BtoA_losses, label="gen_BtoA_loss")

# %%
plt.plot(dis_A_losses, label="dis_A_losses")

# %%
plt.plot(dis_B_losses, label="dis_B_losses")
