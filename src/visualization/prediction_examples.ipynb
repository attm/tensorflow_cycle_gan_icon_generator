# %%
import matplotlib.pyplot as plt
from os.path import join as pjoin
import numpy as np


cwd = "/workspaces/cycle_gan_icons_generator"
TRANSFORMED_IMAGES_DATASET = pjoin(cwd, "data", "transformed", "transformed.npy")

data = np.load(TRANSFORMED_IMAGES_DATASET)
print(data.shape)
# Out:
# (1, 60, 60, 3)

# %%
data = data.reshape(60, 60, 3)
plt.imshow(data)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
